# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
import time
from pprint import pprint
import pandas as pd

# %%
regions = pd.read_pickle('regions_cars24.pkl')

all_region_urls = list(regions.RegionURL)
print(all_region_urls)
# Out:
# ['https://www.cars24.com/buy-used-cars-bangalore/', 'https://www.cars24.com/buy-used-cars-delhi-ncr/', 'https://www.cars24.com/buy-used-cars-hyderabad/', 'https://www.cars24.com/buy-used-cars-chennai/', 'https://www.cars24.com/buy-used-cars-mumbai/', 'https://www.cars24.com/buy-used-cars-pune/', 'https://www.cars24.com/buy-used-cars-ahmedabad/', 'https://www.cars24.com/buy-used-cars-noida/', 'https://www.cars24.com/buy-used-cars-new-delhi/', 'https://www.cars24.com/buy-used-cars-gurgaon/', 'https://www.cars24.com/buy-used-cars-kochi/', 'https://www.cars24.com/buy-used-cars-coimbatore/', 'https://www.cars24.com/buy-used-cars-surat/', 'https://www.cars24.com/buy-used-cars-kolkata/', 'https://www.cars24.com/buy-used-cars-nagpur/', 'https://www.cars24.com/buy-used-cars-lucknow/', 'https://www.cars24.com/buy-used-cars-chandigarh/', 'https://www.cars24.com/buy-used-cars-ghaziabad/', 'https://www.cars24.com/buy-used-cars-patna/', 'https://www.cars24.com/buy-used-cars-jaipur/', 'https://www.cars24.com/buy-used-cars-faridabad/', 'https://www.cars24.com/buy-used-cars-vadodara/', 'https://www.cars24.com/buy-used-cars-indore/', 'https://www.cars24.com/buy-used-cars-rajkot/', 'https://www.cars24.com/buy-used-cars-agra/', 'https://www.cars24.com/buy-used-cars-mysore/', 'https://www.cars24.com/buy-used-cars-trivandrum/']

# %%
retryCount = 3
carLinks   = []

for url in all_region_urls: 
    options = webdriver.ChromeOptions()
    options.headless = True
    driver = webdriver.Chrome(service = ChromeService(
        ChromeDriverManager().install()), options = options)
    print(f"fetching data from {url=}")
    driver.get(url)
    print('waiting 2 seconds for browser to finish loading')
    time.sleep(2)
    last_height = driver.execute_script('return document.body.scrollHeight')
    while True: 
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        print('waiting 2 seconds for car details to load after scroll')
        time.sleep(2)
        new_height = driver.execute_script('return document.body.scrollHeight')
        print(f"{new_height=} and {last_height=}")
        if new_height == last_height:
            print(f"{retryCount=}")
            retryCount=retryCount-1
            if retryCount<1: 
                break
        last_height = new_height

    time.sleep(5)
    cars = driver.find_elements(By.CSS_SELECTOR, 'a.IIJDn')
    print(f"No. of Cars: {len(cars)}")
    for car in cars: 
        carLinks.append(car.get_attribute('href'))
    driver.quit()
    print('waiting 10 seconds before next region starts')
    time.sleep(10)
# Out:
# fetching data from url='https://www.cars24.com/buy-used-cars-bangalore/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=17284 and last_height=9573
# waiting 2 seconds for car details to load after scroll
# new_height=41949 and last_height=17284
# waiting 2 seconds for car details to load after scroll
# new_height=66583 and last_height=41949
# waiting 2 seconds for car details to load after scroll
# new_height=85175 and last_height=66583
# waiting 2 seconds for car details to load after scroll
# new_height=100956 and last_height=85175
# waiting 2 seconds for car details to load after scroll
# new_height=116317 and last_height=100956
# waiting 2 seconds for car details to load after scroll
# new_height=128844 and last_height=116317
# waiting 2 seconds for car details to load after scroll
# new_height=140713 and last_height=128844
# waiting 2 seconds for car details to load after scroll
# new_height=149609 and last_height=140713
# waiting 2 seconds for car details to load after scroll
# new_height=164728 and last_height=149609
# waiting 2 seconds for car details to load after scroll
# new_height=183112 and last_height=164728
# waiting 2 seconds for car details to load after scroll
# new_height=186563 and last_height=183112
# waiting 2 seconds for car details to load after scroll
# new_height=186563 and last_height=186563
# retryCount=3
# waiting 2 seconds for car details to load after scroll
# new_height=186563 and last_height=186563
# retryCount=2
# waiting 2 seconds for car details to load after scroll
# new_height=186563 and last_height=186563
# retryCount=1
# No. of Cars: 1173
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-delhi-ncr/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=26864 and last_height=9711
# waiting 2 seconds for car details to load after scroll
# new_height=48223 and last_height=26864
# waiting 2 seconds for car details to load after scroll
# new_height=51477 and last_height=48223
# waiting 2 seconds for car details to load after scroll
# new_height=60773 and last_height=51477
# waiting 2 seconds for car details to load after scroll
# new_height=70047 and last_height=60773
# waiting 2 seconds for car details to load after scroll
# new_height=73304 and last_height=70047
# waiting 2 seconds for car details to load after scroll
# new_height=76093 and last_height=73304
# waiting 2 seconds for car details to load after scroll
# new_height=79347 and last_height=76093
# waiting 2 seconds for car details to load after scroll
# new_height=88643 and last_height=79347
# waiting 2 seconds for car details to load after scroll
# new_height=94655 and last_height=88643
# waiting 2 seconds for car details to load after scroll
# new_height=94655 and last_height=94655
# retryCount=0
# No. of Cars: 560
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-hyderabad/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=37123 and last_height=11203
# waiting 2 seconds for car details to load after scroll
# new_height=61523 and last_height=37123
# waiting 2 seconds for car details to load after scroll
# new_height=79155 and last_height=61523
# waiting 2 seconds for car details to load after scroll
# new_height=90895 and last_height=79155
# waiting 2 seconds for car details to load after scroll
# new_height=99833 and last_height=90895
# waiting 2 seconds for car details to load after scroll
# new_height=99380 and last_height=99833
# waiting 2 seconds for car details to load after scroll
# new_height=99380 and last_height=99380
# retryCount=-1
# No. of Cars: 606
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-chennai/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=38742 and last_height=9486
# waiting 2 seconds for car details to load after scroll
# new_height=60498 and last_height=38742
# waiting 2 seconds for car details to load after scroll
# new_height=78288 and last_height=60498
# waiting 2 seconds for car details to load after scroll
# new_height=93282 and last_height=78288
# waiting 2 seconds for car details to load after scroll
# new_height=94100 and last_height=93282
# waiting 2 seconds for car details to load after scroll
# new_height=94100 and last_height=94100
# retryCount=-2
# No. of Cars: 573
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-mumbai/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=40531 and last_height=11325
# waiting 2 seconds for car details to load after scroll
# new_height=62358 and last_height=40531
# waiting 2 seconds for car details to load after scroll
# new_height=80476 and last_height=62358
# waiting 2 seconds for car details to load after scroll
# new_height=92468 and last_height=80476
# waiting 2 seconds for car details to load after scroll
# new_height=98952 and last_height=92468
# waiting 2 seconds for car details to load after scroll
# new_height=98952 and last_height=98952
# retryCount=-3
# No. of Cars: 592
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-pune/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=35878 and last_height=9433
# waiting 2 seconds for car details to load after scroll
# new_height=57159 and last_height=35878
# waiting 2 seconds for car details to load after scroll
# new_height=75115 and last_height=57159
# waiting 2 seconds for car details to load after scroll
# new_height=85097 and last_height=75115
# waiting 2 seconds for car details to load after scroll
# new_height=85097 and last_height=85097
# retryCount=-4
# No. of Cars: 515
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-ahmedabad/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=13647 and last_height=9025
# waiting 2 seconds for car details to load after scroll
# new_height=13647 and last_height=13647
# retryCount=-5
# No. of Cars: 200
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-noida/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=16010 and last_height=8135
# waiting 2 seconds for car details to load after scroll
# new_height=28095 and last_height=16010
# waiting 2 seconds for car details to load after scroll
# new_height=40462 and last_height=28095
# waiting 2 seconds for car details to load after scroll
# new_height=43506 and last_height=40462
# waiting 2 seconds for car details to load after scroll
# new_height=50152 and last_height=43506
# waiting 2 seconds for car details to load after scroll
# new_height=50152 and last_height=50152
# retryCount=-6
# No. of Cars: 294
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-new-delhi/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=45191 and last_height=9486
# waiting 2 seconds for car details to load after scroll
# new_height=58882 and last_height=45191
# waiting 2 seconds for car details to load after scroll
# new_height=58882 and last_height=58882
# retryCount=-7
# No. of Cars: 340
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-gurgaon/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=29323 and last_height=9515
# waiting 2 seconds for car details to load after scroll
# new_height=36042 and last_height=29323
# waiting 2 seconds for car details to load after scroll
# new_height=36042 and last_height=36042
# retryCount=-8
# No. of Cars: 194
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-kochi/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=28257 and last_height=9440
# waiting 2 seconds for car details to load after scroll
# new_height=28257 and last_height=28257
# retryCount=-9
# No. of Cars: 142
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-coimbatore/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=19244 and last_height=7332
# waiting 2 seconds for car details to load after scroll
# new_height=19244 and last_height=19244
# retryCount=-10
# No. of Cars: 98
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-surat/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=25602 and last_height=8075
# waiting 2 seconds for car details to load after scroll
# new_height=25602 and last_height=25602
# retryCount=-11
# No. of Cars: 132
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-kolkata/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=23580 and last_height=8087
# waiting 2 seconds for car details to load after scroll
# new_height=23580 and last_height=23580
# retryCount=-12
# No. of Cars: 121
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-nagpur/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=12664 and last_height=8061
# waiting 2 seconds for car details to load after scroll
# new_height=12664 and last_height=12664
# retryCount=-13
# No. of Cars: 40
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-lucknow/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=22333 and last_height=8595
# waiting 2 seconds for car details to load after scroll
# new_height=22333 and last_height=22333
# retryCount=-14
# No. of Cars: 100
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-chandigarh/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=23478 and last_height=8193
# waiting 2 seconds for car details to load after scroll
# new_height=23478 and last_height=23478
# retryCount=-15
# No. of Cars: 118
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-ghaziabad/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=21272 and last_height=7402
# waiting 2 seconds for car details to load after scroll
# new_height=21272 and last_height=21272
# retryCount=-16
# No. of Cars: 108
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-patna/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=19628 and last_height=7463
# waiting 2 seconds for car details to load after scroll
# new_height=19628 and last_height=19628
# retryCount=-17
# No. of Cars: 94
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-jaipur/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=16424 and last_height=7284
# waiting 2 seconds for car details to load after scroll
# new_height=16424 and last_height=16424
# retryCount=-18
# No. of Cars: 78
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-faridabad/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=17709 and last_height=8181
# waiting 2 seconds for car details to load after scroll
# new_height=17709 and last_height=17709
# retryCount=-19
# No. of Cars: 83
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-vadodara/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=20063 and last_height=8129
# waiting 2 seconds for car details to load after scroll
# new_height=20063 and last_height=20063
# retryCount=-20
# No. of Cars: 97
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-indore/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=17107 and last_height=7463
# waiting 2 seconds for car details to load after scroll
# new_height=17107 and last_height=17107
# retryCount=-21
# No. of Cars: 79
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-rajkot/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=14148 and last_height=7254
# waiting 2 seconds for car details to load after scroll
# new_height=14148 and last_height=14148
# retryCount=-22
# No. of Cars: 63
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-agra/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=9886 and last_height=7188
# waiting 2 seconds for car details to load after scroll
# new_height=9886 and last_height=9886
# retryCount=-23
# No. of Cars: 37
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-mysore/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=9071 and last_height=7256
# waiting 2 seconds for car details to load after scroll
# new_height=9071 and last_height=9071
# retryCount=-24
# No. of Cars: 31
# waiting 10 seconds before next region starts
# fetching data from url='https://www.cars24.com/buy-used-cars-trivandrum/'
# waiting 2 seconds for browser to finish loading
# waiting 2 seconds for car details to load after scroll
# new_height=8720 and last_height=7326
# waiting 2 seconds for car details to load after scroll
# new_height=8720 and last_height=8720
# retryCount=-25
# No. of Cars: 28
# waiting 10 seconds before next region starts

# %%
print(len(carLinks))
# Out:
# 6496

# %%
cars_cars24 = pd.DataFrame({'carURLs':carLinks})
cars_cars24.to_pickle('cars_cars24.pkl')

# %%
cars_cars24.shape
# Out:
# (6496, 1)
